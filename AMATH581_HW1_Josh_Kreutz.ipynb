# %%
# Josh Kreutz
# 9/30/2024 
# AMATH 581 HW #1

### Problem 1 ###

import numpy as np

### Newton-Raphson Method ###

# Initial variables
x = np.array([-1.6]) # Initial Guess
iterN = [] # List for storing Newton Raphson iterations
iter = 0 # Initial iteration value

# Loop for Newton Raphson Method
for j in range(1000):
    x = np.append(x, x[j] - (np.sin(3 * x[j]) * x[j] - np.exp(x[j])) / (np.sin(3 * x[j]) + np.cos(3 * x[j]) * 3 * x[j] - np.exp(x[j])))
    fc = (np.sin(3 * x[j]) * x[j] - np.exp(x[j]))
    iter += 1
    iterN.append(iter)
    
    if abs(fc) < 1e-6: # Check until tolerance is met
        break

A1 = x # Store A1 array

### Bisection Method ###


# Initial variables
xr = -0.4 
xl = -0.7
x_mid = []
iterN2 = []
iter2 = 0

# Loop for Bisection Method
for i in range(0, 100):
    xc = (xr + xl) / 2
    fc2 = (np.sin(3 * xc) * xc - np.exp(xc))
    iter2 += 1
    iterN2.append(iter2)
    x_mid.append(xc)
    
    if (fc2 > 0):
           xl = xc
    else:
           xr = xc

    if (abs(fc2) < 1e-6): # Check until tolerance is met
        break

iterations = [iter, iter2]; # Store iteration list

A2 = np.array(x_mid) # Convert list and store A2 array 

A3 = np.array(iterations) # Convert list and store A3 array

### Problem 2 ###

# Initialize arrays
A = np.array([[1, 2], [-1, 1]])
B = np.array([[2, 0], [0, 2]])
C = np.array([[2, 0, -3], [0, 0, -1]])
D = np.array([[1, 2], [2, 3], [-1, 0]])
q = np.array([1, 0])
r = np.array([0, 1])
s = np.array([1, 2, -1])

# Solve arrays
Q = A + B
A4 = Q 

W = 3 * q - 4 * r
A5 = W

E = A @ q
A6 = E

R = B @ (q - r)
A7 = R

T = D @ q
A8 = T

Y = D @ r + s
A9 = Y

U = A @ B
A10 = U

I = B @ C
A11 = I

O = C @ D
A12 = O
